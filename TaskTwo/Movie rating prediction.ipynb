# %% [markdown]
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np

# %%
movie = pd.read_csv("C:/Users/ss/Downloads/TaskTwo/IMDb Movies India.csv", encoding="latin1")
movie
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %%
movie.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
movie.describe()
# Out:
#             Rating
# count  7919.000000
# mean      5.841621
# std       1.381777
# min       1.100000
# 25%       4.900000
# 50%       6.000000
# 75%       6.800000
# max      10.000000

# %% [markdown]
# #### Describe displays the statistics of numeric columns only

# %% [markdown]
# ## Data Cleaning

# %%
movie.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %% [markdown]
# All columns except name is haivng null/missing values

# %%
movie.dropna(subset=["Rating"], inplace=True)

# %%
movie.isnull().sum()
# Out:
# Name           0
# Year           0
# Duration    2068
# Genre        102
# Rating         0
# Votes          0
# Director       5
# Actor 1      125
# Actor 2      200
# Actor 3      292
# dtype: int64

# %%
movie.dropna(subset=['Actor 1', 'Actor 2', 'Actor 3', 'Director', 'Genre'], inplace = True)

# %%
movie.isnull().sum()
# Out:
# Name           0
# Year           0
# Duration    1899
# Genre          0
# Rating         0
# Votes          0
# Director       0
# Actor 1        0
# Actor 2        0
# Actor 3        0
# dtype: int64

# %%
movie.head()
# Out:
#                                  Name    Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                             #Yaaram  (2019)  110 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 8                  ?: A Question Mark  (2012)   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# ...

# %% [markdown]
# We need to convert (2019) to 2019 in Year, remove min from Duration, comma from Votes

# %%
movie['Votes'] = movie['Votes'].str.replace(',','').astype(int)

# %%
movie['Duration'] = movie['Duration'].str.strip('min')

# %%
movie['Year'] = movie['Year'].str.strip('()').astype(int)

# %%
movie.head()
# Out:
#                                  Name  Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  2019     109
# 3                             #Yaaram  2019     110
# 5                ...Aur Pyaar Ho Gaya  1997     147
# 6                           ...Yahaan  2005     142
# 8                  ?: A Question Mark  2012      82
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4   1086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# 5  Aishwarya Rai Bachchan    Shammi Kapoor
# ...

# %%
movie.isnull().sum()
# Out:
# Name           0
# Year           0
# Duration    1899
# Genre          0
# Rating         0
# Votes          0
# Director       0
# Actor 1        0
# Actor 2        0
# Actor 3        0
# dtype: int64

# %%
movie['Duration'] = pd.to_numeric(movie['Duration'], errors='coerce')

# %%
movie['Duration'] = movie['Duration'].fillna(movie['Duration'].median())

#Handling missing values - replacing with the median value. (The median is a statistical measure that represents the middle value in a set of numbers
# when the numbers are arranged in order. If there is an odd number of values, the median is the middle value.
#If there is an even number of values, the median is the average of the two middle values

# %%
movie.isnull().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7558 entries, 1 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      7558 non-null   object
#  1   Year      7558 non-null   int32
#  2   Duration  7558 non-null   float64
#  3   Genre     7558 non-null   object
#  4   Rating    7558 non-null   float64
#  5   Votes     7558 non-null   int32
#  6   Director  7558 non-null   object
#  7   Actor 1   7558 non-null   object
#  8   Actor 2   7558 non-null   object
#  9   Actor 3   7558 non-null   object
# dtypes: float64(2), int32(2), object(6)
# memory usage: 590.5+ KB

# %% [markdown]
# Now the dataa is clean. Lets move on to exploring it.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# we are finding top 10 movies based on rating

# %%
toptenmovies = movie.loc[movie['Rating'].sort_values(ascending=False)[:10].index]
toptenmovies
# Out:
#                       Name  Year  Duration                   Genre  Rating  \
# 8339       Love Qubool Hai  2020      94.0          Drama, Romance    10.0
# 5410            Half Songs  2021      79.0          Music, Romance     9.7
# 2563                 Breed  2020     135.0                   Drama     9.6
# 14222  The Reluctant Crime  2020     113.0                   Drama     9.4
# 5077          Gho Gho Rani  2019     105.0        History, Romance     9.4
# 6852                  June  2021      93.0                   Drama     9.4
# 12673   Secrets of Sinauli  2021      56.0    Documentary, History     9.3
# 5125           God of gods  2019      90.0             Documentary     9.3
# 8344          Love Sorries  2021     101.0  Comedy, Drama, Romance     9.3
# 1314          Ashok Vatika  2018      97.0                   Drama     9.3
#
#        Votes         Director            Actor 1          Actor 2  \
# 8339       5  Saif Ali Sayeed          Ahaan Jha   Mahesh Narayan
# ...

# %% [markdown]
# ### Distribution of top 10 movies with respect to raating

# %%
sns.histplot(data = toptenmovies, x="Year", hue="Rating", multiple="stack")
plt.title('Distribution of Top 10 Movies')
plt.xlabel('Year')
plt.ylabel('Rating')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distribution of Genre using pie chart

# %%
# Initially we need to calculate count for each category of genre and put it into a df.
genrecounting = movie['Genre'].value_counts().reset_index()
genrecounting.columns = ['Genre', 'Count']
topgenres = genrecounting.head(5)
topgenres
# Out:
#                   Genre  Count
# 0                 Drama   1137
# 1        Drama, Romance    443
# 2  Action, Crime, Drama    417
# 3                Action    391
# 4         Drama, Family    291

# %%
# now we can use pie chart to plot the top 5 genres


plt.pie(topgenres['Count'], labels=topgenres['Genre'], autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Movie Genre Distribution', fontsize=16)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Distribution of top directors by movie rating

# %%
# Group the data by director and calculate the average rating
directorbyagrating = movie.groupby('Director')['Rating'].mean().reset_index()
#We need to reset index if we use aggregation

directorbyagrating = directorbyagrating.sort_values(by='Rating', ascending=False)

top_directors = directorbyagrating.head(10)
top_directors
# Out:
#              Director  Rating
# 2243  Saif Ali Sayeed    10.0
# 2560      Sriram Raja     9.7
# 504       Bobby Kumar     9.6
# 322     Arvind Pratap     9.4
# 1513     Munni Pankaj     9.4
# 2598   Suhrud Godbole     9.4
# 1601     Nikhil Mahar     9.3
# 2809     Venkatesh Bk     9.3
# 1879    Rahul Mallick     9.3
# 1864   Raghav Jairath     9.3

# %% [markdown]
# we have created a df with aggregating director and avg of rating column

# %%
sns.barplot(data=top_directors, x='Rating', y='Director', palette='viridis')

plt.title('Top Directors by Average Rating', fontsize=16)
plt.xlabel('Average Rating', fontsize=14)
plt.ylabel('Director', fontsize=14)

plt.show()
# Out:
# C:\Users\ss\AppData\Local\Temp\ipykernel_14088\3755933635.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_directors, x='Rating', y='Director', palette='viridis')

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### 1. No. of Votes vs Movie rating

# %%
# we are using line plot to see relation between votes and movie rating 
sns.lineplot(data=movie, x='Rating', y='Votes')

plt.title('Votes vs. Rating', fontsize=16)
plt.xlabel('Rating', fontsize=14)
plt.ylabel('Votes', fontsize=14)

plt.show()

# %% [markdown]
# #### 2. Top Actors by Number of movies

# %%
actorcounting = movie['Actor 1'].value_counts().reset_index()
actorcounting.columns = ['Actor', 'MovieCount']

topactors = actorcounting.head(10)
topactors
# Out:
#                 Actor  MovieCount
# 0           Jeetendra         140
# 1          Dharmendra         134
# 2  Mithun Chakraborty         130
# 3         Ashok Kumar         125
# 4       Rajesh Khanna         118
# 5    Amitabh Bachchan         116
# 6           Dev Anand          90
# 7       Shashi Kapoor          88
# 8        Akshay Kumar          82
# 9         Sanjay Dutt          73

# %%
sns.barplot(data=topactors, x='MovieCount', y='Actor', orient='h')

# Set plot labels and title
plt.title('Top Actors by Number of Movies', fontsize=16)
plt.xlabel('Number of Movies', fontsize=14)
plt.ylabel('Actor', fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# #### 4. Distribution of number of movie released every year

# %%
yearlymoviecounting = movie['Year'].value_counts().reset_index()
yearlymoviecounting.columns = ['Year', 'MovieCount']

yearlymoviecounting = yearlymoviecounting.sort_values(by='Year')
yearlymoviecounting
# Out:
#     Year  MovieCount
# 91  1917           1
# 88  1931           3
# 89  1932           2
# 86  1933           4
# 90  1934           2
# ..   ...         ...
# 1   2017         223
# 2   2018         214
# 0   2019         238
# 9   2020         157
# 49  2021          69
#
# [92 rows x 2 columns]

# %%
# lets plot lineplot to see number of movie released every year
sns.lineplot(data=yearlymoviecounting, x='Year', y='MovieCount')

plt.title('Number of Movies Released Every Year', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of Movies Released', fontsize=14)

plt.show()

# %% [markdown]
# It is seen from the graph that the number of movies kept on increasing every year.

# %% [markdown]
# conditional bivariate analysis

# %% [markdown]
# #### 5.Distribution of Movies with rating greater than 8 and votes greater than 10000

# %%
filtereddata = movie[(movie['Rating'] > 8) & (movie['Votes'] > 10000)]
filtereddata.head(10)
# Out:
#                     Name  Year  Duration                    Genre  Rating  \
# 75              3 Idiots  2009     170.0            Comedy, Drama     8.4
# 173          A Wednesday  2008     104.0     Action, Crime, Drama     8.1
# 981                Anand  1971     122.0           Drama, Musical     8.3
# 1009     Andaz Apna Apna  1994     160.0  Action, Comedy, Romance     8.1
# 1019           Andhadhun  2018     139.0      Crime, Drama, Music     8.2
# 1285          Article 15  2019     130.0    Crime, Drama, Mystery     8.2
# 1877              Barfi!  2012     151.0   Comedy, Drama, Romance     8.1
# 2065  Bhaag Milkha Bhaag  2013     186.0  Biography, Drama, Sport     8.2
# 2412               Black  2005     122.0                    Drama     8.2
# 2425        Black Friday  2004     143.0     Action, Crime, Drama     8.5
#
#        Votes                 Director             Actor 1  \
# 75    357889          Rajkumar Hirani          Aamir Khan
# ...

# %%
# lets plot with barplot and give color to rating column
plt.figure(figsize=(15, 6))
ax=sns.barplot(data=filtereddata,x='Name',y='Votes',hue='Rating',dodge=False,width=0.5,palette='muted')


ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')
ax.legend(loc='upper right')
ax.set_xlabel('Movie Name')
ax.set_ylabel('Votes')
ax.set_title('Movies with rating greater than 8 and votes greater than 10000')

plt.show()
# Out:
# C:\Users\ss\AppData\Local\Temp\ipykernel_14088\1206133026.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')

# %% [markdown]
# #### 6. Distribution of Durations of movies by years

# %%
movie['Duration'] = movie['Duration'].astype(int)
movie['Year'] = movie['Year'].astype(int)
plt.figure(figsize=(13, 6))

sns.lineplot(data=movie,x='Year',y='Duration',errorbar=None)
plt.xlabel('Year')
plt.ylabel('Duration in minutes')
plt.title('Duration of movies by year')
plt.xticks(np.arange(1917,2023,5))
plt.show()

# %% [markdown]
# #### 7. Distribution of Number of movies each genre

# %%
movie['Genre'] = movie['Genre'].str.split(',')

# Create a new DataFrame with one row for each genre
genre_df = movie.explode('Genre')
genre_df
# Out:
#                                      Name  Year  Duration     Genre  Rating  \
# 1      #Gadhvi (He thought he was Gandhi)  2019       109     Drama     7.0
# 3                                 #Yaaram  2019       110    Comedy     4.4
# 3                                 #Yaaram  2019       110   Romance     4.4
# 5                    ...Aur Pyaar Ho Gaya  1997       147    Comedy     4.7
# 5                    ...Aur Pyaar Ho Gaya  1997       147     Drama     4.7
# ...                                   ...   ...       ...       ...     ...
# 15504                 Zulm Ko Jala Doonga  1988       135    Action     4.6
# 15505                               Zulmi  1999       129    Action     4.5
# 15505                               Zulmi  1999       129     Drama     4.5
# 15508                        Zulm-O-Sitam  1998       130    Action     6.2
# 15508                        Zulm-O-Sitam  1998       130     Drama     6.2
#
# ...

# %%
#lets plot using count plot
#A count plot is a type of categorical plot in data visualization used to display the count (or frequency) of each category in a categorical variable. 
#It is a specific kind of bar plot where the height of the bar represents the number of observations in each category

plt.figure(figsize=(12, 6))
sns.countplot(data=genre_df, x='Genre', order=genre_df['Genre'].value_counts().index, palette='viridis')

plt.title('Number of Movies for Each Genre', fontsize=16)
plt.xlabel('Number of Movies', fontsize=14)
plt.ylabel('Genre', fontsize=14)
plt.xticks(rotation=90)

plt.show()
# Out:
# C:\Users\ss\AppData\Local\Temp\ipykernel_14088\4228160973.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=genre_df, x='Genre', order=genre_df['Genre'].value_counts().index, palette='viridis')

# %% [markdown]
# #### 8. Distribution of Average rating of movies in each genre

# %%
#need to reset index as we are aggregating the genre
average_rating_by_genre = genre_df.groupby('Genre')['Rating'].mean().reset_index()
average_rating_by_genre = average_rating_by_genre.sort_values(by='Rating', ascending=False)

# %%
plt.figure(figsize=(15,5))
sns.barplot(data=average_rating_by_genre,y="Rating",x='Genre',palette='coolwarm')
plt.xlabel('Genre')
plt.ylabel('Average Rating')
plt.title('Average rating of movies in each genre')
plt.xticks(rotation=90)

plt.show()
# Out:
# C:\Users\ss\AppData\Local\Temp\ipykernel_14088\2700868086.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=average_rating_by_genre,y="Rating",x='Genre',palette='coolwarm')

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# This code performs Label Encoding on categorical columns in the movie DataFrame, such as 'Director', 'Actor 1', 'Actor 2', 'Actor 3', and 'Genre', to convert them into numerical values. The 'Director' and 'Actor' columns are encoded individually by applying fit_transform for each, while the 'Genre' column is first joined into a single string and then encoded. Finally, the resulting transformed data is stored in a new DataFrame called trans_data, with the 'Name' column dropped.

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

trans_data = movie.drop(['Name'],axis=1)
# Transform Director columns
trans_data['Director'] = labelencoder.fit_transform(movie['Director'])

# Transform Actors Columns
trans_data['Actor 1'] = labelencoder.fit_transform(movie['Actor 1'])
trans_data['Actor 2'] = labelencoder.fit_transform(movie['Actor 2'])
trans_data['Actor 3'] = labelencoder.fit_transform(movie['Actor 3'])

trans_data['Genre'] = labelencoder.fit_transform(movie['Genre'].apply(lambda x: ', '.join(x)))

trans_data.head()
# Out:
#    Year  Duration  Genre  Rating  Votes  Director  Actor 1  Actor 2  Actor 3
# 1  2019       109    252     7.0      8       755     1686     2725      373
# 3  2019       110    205     4.4     35      1637     1500      865     2543
# 5  1997       147    175     4.7    827      1881      481       84     2422
# 6  2005       142    315     7.4   1086      2486      878     1346     2996
# 8  2012        82    351     5.6    326       161     2385     1416     1189

# %% [markdown]
# This code applies **Min-Max Scaling** to the `trans_data` DataFrame using `MinMaxScaler` from `sklearn.preprocessing`. It transforms the data to a range between 0 and 1 by scaling each feature in the dataset according to its minimum and maximum values. The scaled data is then converted into a new DataFrame `sc_df`, retaining the original column names from `trans_data`.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
sc_data = scaler.fit_transform(trans_data)
sc_df = pd.DataFrame(sc_data,columns=trans_data.columns)

sc_df.head()
# Out:
#        Year  Duration     Genre    Rating     Votes  Director   Actor 1  \
# 0  0.980769  0.293333  0.607229  0.662921  0.000005  0.255499  0.698426
# 1  0.980769  0.296667  0.493976  0.370787  0.000051  0.553976  0.621375
# 2  0.769231  0.420000  0.421687  0.404494  0.001390  0.636548  0.199254
# 3  0.846154  0.403333  0.759036  0.707865  0.001828  0.841286  0.363712
# 4  0.913462  0.203333  0.845783  0.505618  0.000543  0.054484  0.987987
#
#     Actor 2   Actor 3
# 0  0.979511  0.123102
# 1  0.310927  0.839274
# 2  0.030194  0.799340
# 3  0.483825  0.988779
# 4  0.508986  0.392409

# %%
# correlation
corr_df = trans_data.corr(numeric_only=True)
corr_df['Rating'].sort_values(ascending=False)
# Out:
# Rating      1.000000
# Votes       0.134655
# Genre       0.122565
# Actor 2     0.038852
# Actor 3     0.031550
# Actor 1     0.025089
# Duration   -0.001801
# Director   -0.003678
# Year       -0.194990
# Name: Rating, dtype: float64

# %% [markdown]
# calculates the correlation matrix of the trans_data DataFrame, considering only numeric columns, using the .corr() method. It then sorts the correlation values of the 'Rating' column in descending order to identify which variables are most strongly correlated with the rating.
#
# Correlation is used to identify the strength and direction of the relationship between two or more variables, helping to understand how they influence each other.

# %%
# lets plot in heatmap
sns.heatmap(corr_df,annot=False,cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# ## Model Building

# %%
# Import modeling Libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
# put data except Rating data
X = trans_data.drop(['Rating'],axis=1)

# Put only Rating data
y = trans_data['Rating']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# The above code splits the `trans_data` DataFrame into features (`X`) by dropping the 'Rating' column and the target variable (`y`) containing only the 'Rating' column, then it divides the data into training and testing sets using a 70-30 split. A **Linear Regression model** is then created and trained on the training data (`X_train`, `y_train`) to learn the relationship between the features and the target variable.

# %%
X_test = np.array(X_test)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# C:\Users\ss\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([6.38173569, 6.27438422, 6.24148256, ..., 5.6990634 , 6.25823896,
#        6.09526622])

# %%
print('R2 score: ',r2_score(y_test,y_pred))
print('Mean squared error: ',mean_squared_error(y_test,y_pred))
print('Mean absolute error: ',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score:  0.08483347672034802
# Mean squared error:  1.6972873264362
# Mean absolute error:  1.0286370452288052

# %%
print(y_test)
# Out:
# 6241     7.4
# 3321     4.9
# 6117     6.5
# 5975     5.7
# 6653     7.0
#         ...
# 14566    3.5
# 10966    5.2
# 10168    2.7
# 14796    4.9
# 2785     8.0
# Name: Rating, Length: 2268, dtype: float64

# %% [markdown]
# This code splits the `trans_data` DataFrame into features (`X`) and target (`y`), then divides them into training and testing sets. A **Linear Regression model** is trained on the training data, and predictions are made on the test set (`X_test`). The model's performance is evaluated using metrics like **R² score**, **Mean Squared Error (MSE)**, and **Mean Absolute Error (MAE)**, and the actual test values (`y_test`) are printed for comparison.

# %% [markdown]
# Using this process, we evaluate the performance of the **Linear Regression model** that predicts the 'Rating' based on other features in the dataset. Specifically:
#
# 1. **R² score** tells us how well the model explains the variance in the target variable ('Rating'). A higher R² indicates a better fit.
# 2. **Mean Squared Error (MSE)** and **Mean Absolute Error (MAE)** provide insights into the model's accuracy by measuring the average difference between predicted and actual values. Lower values for MSE and MAE indicate better model performance.
#
# In summary, these metrics help assess the model's predictive power and how closely its predictions match the actual ratings in the test data.
